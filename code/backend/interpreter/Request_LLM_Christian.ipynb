# %%
# Anbindung LLM Christian

# %%
import json
from openai import OpenAI
import requests
import httpx

with open("TS-Scanner.json") as f:
    env = json.load(f)

with open("llm.codebar.net.json") as f:
    codebar = json.load(f)

access = {v["name"]: v["value"] for v in env["variables"] if v.get("enabled", True)}


class ScrubTransport(httpx.HTTPTransport):
    def handle_request(self, request):
        request.headers["user-agent"] = "Mozilla/5.0"
        for name in [h for h in request.headers if h.lower().startswith("x-stainless")]:
            del request.headers[name]
        return super().handle_request(request)

client = OpenAI(
    base_url=access["url"],
    api_key=access["token"],
    http_client=httpx.Client(transport=ScrubTransport()),
)

models = client.models.list()
print([m.id for m in models.data])
# Out:
# ['qwen2.5:7b-instruct', 'qwen2.5:32b-instruct-q4_K_M', 'qwen2.5-coder:32b', 'llama3.3:70b-instruct-q4_K_M', 'qwen3:32b', 'qwen3:30b-a3b', 'qwen3.5:4b', 'qwen3.5:9b', 'qwen3.6:35b', 'deepseek-r1:70b', 'gpt-oss:20b']

# %%
import requests

url = access['url'].rstrip('/') + '/models'   # adjust /v1 if needed
headers = {"Authorization": f"Bearer {access['token']}"}

r = requests.get(url, headers=headers)
print("Status:", r.status_code)
print("Headers:", dict(r.headers))
print("Body:", r.text[:1000])
# Out:
# Status: 200
# Headers: {'Date': 'Fri, 29 May 2026 08:56:59 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'cloudflare', 'Cf-Cache-Status': 'DYNAMIC', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=b3Iyi%2B%2FPhZz3u2vj%2FhT0uNLQFq6o1ruU%2F%2B4K9W6JYVQoyVmcXT789P4ZXc6XA6BTOJ00iT%2Fhq%2F27hmuu5ZpnuKUHJtlcU7SbQDh%2B3EwUFH3X5NzLNEKwUygm2fGlgi%2F1q5E%3D"}]}', 'Content-Encoding': 'gzip', 'CF-RAY': 'a03449fc2848bc4a-ZRH', 'alt-svc': 'h3=":443"; ma=86400'}
# Body: {"data":[{"id":"qwen2.5:7b-instruct","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen2.5:32b-instruct-q4_K_M","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen2.5-coder:32b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"llama3.3:70b-instruct-q4_K_M","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen3:32b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen3:30b-a3b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen3.5:4b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen3.5:9b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"qwen3.6:35b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"deepseek-r1:70b","object":"model","created":1677610602,"owned_by":"openai"},{"id":"gpt-oss:20b","object":"model","created":1677610602,"owned_by":"openai"}],"object":"list"}

# %%
def chat(prompt, model="qwen2.5:32b-instruct-q4_K_M", system=None, stream=False, **kwargs):
    messages = []
    if system:
        messages.append({"role": "system", "content": system})
    messages.append({"role": "user", "content": prompt})

    if stream:
        text = ""
        for chunk in client.chat.completions.create(
            model=model, messages=messages, stream=True, **kwargs
        ):
            delta = chunk.choices[0].delta.content or ""
            print(delta, end="", flush=True)
            text += delta
        print()
        return text

    resp = client.chat.completions.create(model=model, messages=messages, **kwargs)
    return resp.choices[0].message.content

# %% [markdown]
# ## Test LLM

# %%
print(chat("Was ist eine Tierseuche? Erkläre in 100 Zeichen"))
# Out:
# Eine Tierseuche ist eine ansteckende Krankheit bei Tieren, die sich schnell verbreitet und große Populationen gefährdet.

# %%
# !python interpreter.py -i ../../../data/unstructured/gefluegelnews/disease_reports.jsonl  -o ../../../data/unstructured/gefluegelnews/disease_reports_embeddings.jsonl --progress-every 100
# Out:
# ['qwen2.5:7b-instruct', 'qwen2.5:32b-instruct-q4_K_M', 'qwen2.5-coder:32b', 'llama3.3:70b-instruct-q4_K_M', 'qwen3:32b', 'qwen3:30b-a3b', 'qwen3.5:4b', 'qwen3.5:9b', 'qwen3.6:35b', 'deepseek-r1:70b', 'gpt-oss:20b']
# Traceback (most recent call last):
#   File "/home/tobias.blatter@blv.admin.ch/GovTech-Hackathon-2026-Tierseuchen-Screener/code/backend/interpreter/interpreter.py", line 245, in <module>
#     raise FileNotFoundError(f"system prompt not found: {prompt_path}")
# FileNotFoundError: system prompt not found: SystemPrompt.md

# %%
# !python gen_schema.py SystemPromptGN.md -o schema_GN.py
# !python gen_schema.py SystemPromptPAFF.md -o schema_PAFF.py
# Out:
# wrote schema_GN.py (23 fields)
# wrote schema_PAFF.py (4 fields)

# %%
# !python interpreter.py --system-prompt SystemPromptGN.md --schema schema_GN.py -i ../../../data/unstructured/gefluegelnews/disease_reports.jsonl -o ../../../data/unstructured/gefluegelnews/disease_reports_embeddings.jsonl --progress-every 100 --no-resume
# Out:
# ['qwen2.5:7b-instruct', 'qwen2.5:32b-instruct-q4_K_M', 'qwen2.5-coder:32b', 'llama3.3:70b-instruct-q4_K_M', 'qwen3:32b', 'qwen3:30b-a3b', 'qwen3.5:4b', 'qwen3.5:9b', 'qwen3.6:35b', 'deepseek-r1:70b', 'gpt-oss:20b']
# processing ../../../data/unstructured/gefluegelnews/disease_reports.jsonl -> ../../../data/unstructured/gefluegelnews/disease_reports_embeddings.jsonl
#
# all done

# %%
import json
import pandas as pd

records = [json.loads(l) for l in open("../../../data/unstructured/gefluegelnews/disease_reports_embeddings.jsonl", encoding="utf-8")]
df = pd.json_normalize(records)   # flattens consequence.politisch etc.

cols = ["Disease", "DiseaseSubtype", "InEurope","Fulltext"
        "consequence.politisch", "consequence.sozial", "consequence.wirtschaftlich",
        "_error"]

df[[c for c in cols if c in df.columns]].iloc[1].values
# Out:
# array([], dtype=float64)

# %%
import importlib.util
from dataclasses import fields

records = [json.loads(l) for l in open("../../../data/unstructured/gefluegelnews/disease_reports_embeddings.jsonl", encoding="utf-8")]
df = pd.json_normalize(records)   # flattens consequence.politisch etc.

spec = importlib.util.spec_from_file_location("_schema", "schema_GN.py")
mod = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod)

cols = [f.name for f in fields(mod.ExtractionSchema)] + ["full_text", "_error"]
df[[c for c in cols if c in df.columns]].iloc[1]
# Out:
# disease_name                                              Avian influenza
# disease_type                                                        viral
# country_or_territory                                              Germany
# is_in_europe                                                         True
# relevance_level                                                    medium
# relevance_rationale     Report discusses industry outlook and politica...
# severity_level                                                        low
# severity_rationale      The report states the disease seems manageable...
# reach_level                                                      national
# reach_rationale         Discussion covers national market orientation,...
# has_consequences                                                     True
# consequences            Political framework described as lacking relia...
# control_measures                                                       []
# prevention_measures     [{'text': 'Enhanced origin labeling '5xD' for ...
# species                                   chickens, turkeys, pigs, cattle
# cases                                                                 NaN
# dead                                                                  NaN
# killed                                                                NaN
# slaughtered                                                          None
# vaccinated                                                            NaN
# confirmation_date                                                     NaN
# result_date                                                           NaN
# status                                                                NaN
# Name: 1, dtype: object

# %%
# !python interpreter.py \
  --system-prompt SystemPromptGN.md \
  --schema schema_GN.py \
  -i ../../../data/unstructured/PAFF_extracted \
  -o ../../../data/unstructured/PAFF_embedded \
  --progress-every 100
# Out:
# ['qwen2.5:7b-instruct', 'qwen2.5:32b-instruct-q4_K_M', 'qwen2.5-coder:32b', 'llama3.3:70b-instruct-q4_K_M', 'qwen3:32b', 'qwen3:30b-a3b', 'qwen3.5:4b', 'qwen3.5:9b', 'qwen3.6:35b', 'deepseek-r1:70b', 'gpt-oss:20b']
# found 15 input file(s) in ../../../data/unstructured/PAFF_extracted
#
# processing reg-com_ahw_20260122_pres-14_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260122_pres-14_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260122_pres-15_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260122_pres-15_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-09_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-09_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-10_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-10_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-11_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-11_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-12_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-12_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-13_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-13_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-14_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-14_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-15_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-15_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260219_pres-18_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-18_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260324_pres-12_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260324_pres-12_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260324_pres-13_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260324_pres-13_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260324_pres-14_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260324_pres-14_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260324_pres-15_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260324_pres-15_extracted.jsonl
#   resuming after 1 already-processed records
#
# processing reg-com_ahw_20260324_pres-17_extracted.json -> ../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260324_pres-17_extracted.jsonl
#   resuming after 1 already-processed records
#
# all done

# %%
import json
import pandas as pd
import importlib.util
from dataclasses import fields

records = [json.loads(l) for l in open("../../../data/unstructured/PAFF_embedded/reg-com_ahw_20260219_pres-13_extracted.jsonl", encoding="utf-8")]
df = pd.json_normalize(records)   # flattens consequence.politisch etc.

spec = importlib.util.spec_from_file_location("_schema", "schema_GN.py")
mod = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod)

cols = [f.name for f in fields(mod.ExtractionSchema)] + ["full_text", "_error"]
df[[c for c in cols if c in df.columns]]
# Out:
#   disease_name disease_type country_or_territory is_in_europe relevance_level  \
# 0         None         None                 None         None            None
#
#   relevance_rationale severity_level severity_rationale reach_level  \
# 0                None           None               None        None
#
#   reach_rationale  ... species cases  dead killed slaughtered vaccinated  \
# 0            None  ...    None  None  None   None        None       None
#
#   confirmation_date result_date status  \
# 0              None        None   None
#
#                                               _error
# 0  json parse: Expecting value: line 1 column 1 (...
#
# [1 rows x 24 columns]
